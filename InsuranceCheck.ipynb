# %%
#Assignment 2

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("insurance.xlsx")

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   gender    1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1337 non-null   float64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull()
# Out:
#         age  gender    bmi  children  smoker  region  charges
# 0     False   False  False     False   False   False    False
# 1     False   False  False     False   False   False    False
# 2     False   False  False     False   False   False    False
# 3     False   False  False     False   False   False    False
# 4     False   False  False     False   False   False    False
# ...     ...     ...    ...       ...     ...     ...      ...
# 1333  False   False  False     False   False   False    False
# 1334  False   False  False     False   False   False    False
# 1335  False   False  False     False   False   False    False
# 1336  False   False  False     False   False   False    False
# 1337  False   False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    1
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # Measure of Central Tendency

# %%
df.charges.mean()
# Out:
# 13270.422265141257

# %%
df.charges.median()
# Out:
# 9382.033

# %%
df.charges.mode()
# Out:
# 0    1639.5631
# Name: charges, dtype: float64

# %%
df.bmi.mode()
# Out:
# 0    32.3
# Name: bmi, dtype: float64

# %%
df.children.mode()
# Out:
# 0    0.0
# Name: children, dtype: float64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1337.000000   1338.000000
# mean     39.207025    30.663397     1.095737  13270.422265
# std      14.049960     6.098187     1.205571  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(28, 18))
plt.title("Charges-Count Histplot", color="#613659", fontsize=22)
plt.xlabel("Charges", color="#613659", fontsize=20)
plt.ylabel("Count", color="#613659", fontsize=20)
sns.histplot(df[["charges"]], color='#887BB0', palette=["#887BB0"])
# Out:
# <Axes: title={'center': 'Charges-Count Histplot'}, xlabel='Charges', ylabel='Count'>

# %%
numeric_columns = df.select_dtypes(include=np.number)
correlation_matrix = numeric_columns.corr()
correlation_matrix
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.043165  0.299008
# bmi       0.109272  1.000000  0.012564  0.198341
# children  0.043165  0.012564  1.000000  0.067830
# charges   0.299008  0.198341  0.067830  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(correlation_matrix, annot=True)
plt.savefig("nishat.png")

# %% [markdown]
# # Handle NAN Value (NAN == NULL)

# %%
#Since there was no null in provided dataframe I edited D781 of the dataframe and made it null.

# %%
Mean_Children = df.children.mean()
Mean_Children
# Out:
# 1.0957367240089753

# %%
df.children = df.children.fillna(Mean_Children)

# %%
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df[781:783]
# Out:
#      age gender    bmi  children smoker     region    charges
# 781   18   male  41.14       0.0     no  southeast  1146.7966
# 782   51   male  35.97       1.0     no  southeast  9386.1613

# %%
df.iloc[781]
# Out:
# age                18
# gender           male
# bmi             41.14
# children          0.0
# smoker             no
# region      southeast
# charges     1146.7966
# Name: 781, dtype: object

# %%
df.children.iloc[781]
# Out:
# 0.0

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()
df7 = df.copy()
df8 = df.copy()
df9 = df.copy()
df10 = df.copy()
df11 = df.copy()
df12 = df.copy()

# %% [markdown]
# # Encoding Using the Replace Method

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
Gender1 = df.gender.unique()
Gender1
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.gender = df.gender.replace(['female', 'male'],[1,2])
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19       1  27.900       0.0    yes  southwest  16884.92400
# 1   18       2  33.770       1.0     no  southeast   1725.55230
# 2   28       2  33.000       3.0     no  southeast   4449.46200
# 3   33       2  22.705       0.0     no  northwest  21984.47061
# 4   32       2  28.880       0.0     no  northwest   3866.85520

# %%
Smoker1 = df.smoker.unique()
Smoker1
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.smoker = df.smoker.replace(['yes', 'no'],[1,0])
df.head()
# Out:
#    age  gender     bmi  children  smoker     region      charges
# 0   19       1  27.900       0.0       1  southwest  16884.92400
# 1   18       2  33.770       1.0       0  southeast   1725.55230
# 2   28       2  33.000       3.0       0  southeast   4449.46200
# 3   33       2  22.705       0.0       0  northwest  21984.47061
# 4   32       2  28.880       0.0       0  northwest   3866.85520

# %%
Region1 = df.region.unique()
Region1
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.region = df.region.replace(['southwest', 'southeast', 'northwest', 'northeast'],[11,22,33,44])
df.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       1  27.900       0.0       1      11  16884.92400
# 1   18       2  33.770       1.0       0      22   1725.55230
# 2   28       2  33.000       3.0       0      22   4449.46200
# 3   33       2  22.705       0.0       0      33  21984.47061
# 4   32       2  28.880       0.0       0      33   3866.85520

# %%
df.corr()
# Out:
#                age    gender       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.043150 -0.025019 -0.002127  0.299008
# gender   -0.020856  1.000000  0.046371  0.017841  0.076185 -0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012564  0.003750 -0.157566  0.198341
# children  0.043150  0.017841  0.012564  1.000000  0.007331 -0.016257  0.067828
# smoker   -0.025019  0.076185  0.003750  0.007331  1.000000  0.002181  0.787251
# region   -0.002127 -0.004588 -0.157566 -0.016257  0.002181  1.000000  0.006208
# charges   0.299008  0.057292  0.198341  0.067828  0.787251  0.006208  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.savefig("nishat.png")

# %% [markdown]
# # Encoding Using the Replace Method (Loop)

# %%
df10.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
columns = ['gender', 'smoker', 'region']
replacement_values = [[1, 2], [1, 0], [11, 22, 33, 44]]

for i, col in enumerate(columns):
    unique_values = df[col].unique()
    df[col] = df[col].replace(unique_values, replacement_values[i])

df.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       1  27.900       0.0       1      11  16884.92400
# 1   18       2  33.770       1.0       0      22   1725.55230
# 2   28       2  33.000       3.0       0      22   4449.46200
# 3   33       2  22.705       0.0       0      33  21984.47061
# 4   32       2  28.880       0.0       0      33   3866.85520

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df1.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
df1.gender = le.fit_transform(df1.gender)
df1.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19       0  27.900       0.0    yes  southwest  16884.92400
# 1   18       1  33.770       1.0     no  southeast   1725.55230
# 2   28       1  33.000       3.0     no  southeast   4449.46200
# 3   33       1  22.705       0.0     no  northwest  21984.47061
# 4   32       1  28.880       0.0     no  northwest   3866.85520

# %%
df1.smoker = le.fit_transform(df1.smoker)
df1.head()
# Out:
#    age  gender     bmi  children  smoker     region      charges
# 0   19       0  27.900       0.0       1  southwest  16884.92400
# 1   18       1  33.770       1.0       0  southeast   1725.55230
# 2   28       1  33.000       3.0       0  southeast   4449.46200
# 3   33       1  22.705       0.0       0  northwest  21984.47061
# 4   32       1  28.880       0.0       0  northwest   3866.85520

# %%
df1.region = le.fit_transform(df1.region)
df1.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900       0.0       1       3  16884.92400
# 1   18       1  33.770       1.0       0       2   1725.55230
# 2   28       1  33.000       3.0       0       2   4449.46200
# 3   33       1  22.705       0.0       0       1  21984.47061
# 4   32       1  28.880       0.0       0       1   3866.85520

# %% [markdown]
# # Label Encoding Using Loop

# %%
df2.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df2.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
for col in df2.columns:
    if df2[col].dtype == np.number:
        continue
    else:
        df2[col] = le.fit_transform(df2[col])

# %%
df2.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0    1       0  27.900       0.0       1       3  16884.92400
# 1    0       1  33.770       1.0       0       2   1725.55230
# 2   10       1  33.000       3.0       0       2   4449.46200
# 3   15       1  22.705       0.0       0       1  21984.47061
# 4   14       1  28.880       0.0       0       1   3866.85520

# %% [markdown]
# # Another Way of Label Encoding Using Loop

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
df3.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
for i in df3.columns:
    if is_numeric_dtype(df3[i]):
        continue
    else:
        df3[i] = le.fit_transform(df3[i])

# %%
df3.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900       0.0       1       3  16884.92400
# 1   18       1  33.770       1.0       0       2   1725.55230
# 2   28       1  33.000       3.0       0       2   4449.46200
# 3   33       1  22.705       0.0       0       1  21984.47061
# 4   32       1  28.880       0.0       0       1   3866.85520

# %% [markdown]
# # One Hot Encoding

# %%
df4.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
dummy = pd.get_dummies(df4['gender'], columns = df4.gender.unique)
dummy.head()
# Out:
#    female   male
# 0    True  False
# 1   False   True
# 2   False   True
# 3   False   True
# 4   False   True

# %%
df4.drop('gender',axis=1,inplace=True)
df4.head()
# Out:
#    age     bmi  children smoker     region      charges
# 0   19  27.900       0.0    yes  southwest  16884.92400
# 1   18  33.770       1.0     no  southeast   1725.55230
# 2   28  33.000       3.0     no  southeast   4449.46200
# 3   33  22.705       0.0     no  northwest  21984.47061
# 4   32  28.880       0.0     no  northwest   3866.85520

# %%
dummy1 = pd.get_dummies(df4['smoker'], columns = df4.smoker.unique)
dummy1.head()
# Out:
#       no    yes
# 0  False   True
# 1   True  False
# 2   True  False
# 3   True  False
# 4   True  False

# %%
df4.drop('smoker',axis=1,inplace=True)
df4.head()
# Out:
#    age     bmi  children     region      charges
# 0   19  27.900       0.0  southwest  16884.92400
# 1   18  33.770       1.0  southeast   1725.55230
# 2   28  33.000       3.0  southeast   4449.46200
# 3   33  22.705       0.0  northwest  21984.47061
# 4   32  28.880       0.0  northwest   3866.85520

# %%
dummy2 = pd.get_dummies(df4['region'], columns = df4.region.unique)
dummy2.head()
# Out:
#    northeast  northwest  southeast  southwest
# 0      False      False      False       True
# 1      False      False       True      False
# 2      False      False       True      False
# 3      False       True      False      False
# 4      False       True      False      False

# %%
df4.drop('region',axis=1,inplace=True)
df4.head()
# Out:
#    age     bmi  children      charges
# 0   19  27.900       0.0  16884.92400
# 1   18  33.770       1.0   1725.55230
# 2   28  33.000       3.0   4449.46200
# 3   33  22.705       0.0  21984.47061
# 4   32  28.880       0.0   3866.85520

# %% [markdown]
# # Dummy Variable Trap

# %%
df5.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
dummy = pd.get_dummies(df5['gender'], columns=df5.gender.unique, drop_first=True,prefix='Gender')
dummy.head()
# Out:
#    Gender_male
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True

# %%
dummy1 = pd.get_dummies(df5['smoker'], columns=df5.smoker.unique, drop_first=True,prefix='Smoker')
dummy1.head()
# Out:
#    Smoker_yes
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False

# %%
dummy2 = pd.get_dummies(df5['region'], columns=df5.gender.unique, drop_first=True,prefix='Region')
dummy2.head()
# Out:
#    Region_northwest  Region_southeast  Region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
df6 = pd.concat([df4, dummy, dummy1, dummy2], axis=1)
df6.head()
# Out:
#    age     bmi  children      charges  Gender_male  Smoker_yes  \
# 0   19  27.900       0.0  16884.92400        False        True
# 1   18  33.770       1.0   1725.55230         True       False
# 2   28  33.000       3.0   4449.46200         True       False
# 3   33  22.705       0.0  21984.47061         True       False
# 4   32  28.880       0.0   3866.85520         True       False
#
#    Region_northwest  Region_southeast  Region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %% [markdown]
# # One Hot Encoding Using Loop

# %%
df7.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
cols = ['gender']
for col in cols:
    dummy = pd.get_dummies(df7[col], drop_first=True, prefix='gender')
    df7 = pd.concat([df7, dummy], axis=1).drop(col, axis=1)

cols = ['smoker']
for col in cols:
    dummy1 = pd.get_dummies(df7[col], drop_first=True, prefix='smoker')
    df7 = pd.concat([df7, dummy1], axis=1).drop(col, axis=1)

cols = ['region']
for col in cols:
    dummy2 = pd.get_dummies(df7[col], drop_first=True, prefix='region')
    df7 = pd.concat([df7, dummy2], axis=1).drop(col, axis=1)

df7.head()
# Out:
#    age     bmi  children      charges  gender_male  smoker_yes  \
# 0   19  27.900       0.0  16884.92400        False        True
# 1   18  33.770       1.0   1725.55230         True       False
# 2   28  33.000       3.0   4449.46200         True       False
# 3   33  22.705       0.0  21984.47061         True       False
# 4   32  28.880       0.0   3866.85520         True       False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %% [markdown]
# # Ordinal Encoding

# %%
df8.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
Gender = df8.gender.unique()
Gender
# Out:
# array(['female', 'male'], dtype=object)

# %%
Smoker = df8.smoker.unique()
Smoker
# Out:
# array(['yes', 'no'], dtype=object)

# %%
Region = df8.region.unique()
Region
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
od = OrdinalEncoder(categories=[Gender])
od1 = OrdinalEncoder(categories=[Smoker])
od2 = OrdinalEncoder(categories=[Region])

# %%
encoded_values = od.fit_transform(df8[['gender']])
encoded_values
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
encoded_values1 = od1.fit_transform(df8[['smoker']])
encoded_values1
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [0.]])

# %%
encoded_values2 = od2.fit_transform(df8[['region']])
encoded_values2
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [0.],
#        [2.]])

# %%
encoded_values = pd.DataFrame(encoded_values,columns=['gender'])
encoded_values.head()
# Out:
#    gender
# 0     0.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
encoded_values1 = pd.DataFrame(encoded_values1,columns=['smoker'])
encoded_values1.head()
# Out:
#    smoker
# 0     0.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
encoded_values2 = pd.DataFrame(encoded_values2,columns=['region'])
encoded_values2.head()
# Out:
#    region
# 0     0.0
# 1     1.0
# 2     1.0
# 3     2.0
# 4     2.0

# %%
df8 = pd.concat([df8.drop(['gender', 'smoker', 'region'], axis=1), encoded_values, encoded_values1, encoded_values2], axis=1)
df8.head()
# Out:
#    age     bmi  children      charges  gender  smoker  region
# 0   19  27.900       0.0  16884.92400     0.0     0.0     0.0
# 1   18  33.770       1.0   1725.55230     1.0     1.0     1.0
# 2   28  33.000       3.0   4449.46200     1.0     1.0     1.0
# 3   33  22.705       0.0  21984.47061     1.0     1.0     2.0
# 4   32  28.880       0.0   3866.85520     1.0     1.0     2.0

# %% [markdown]
# # Ordinal Encoding Using loop

# %%
df9.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
df_encoded = df9.copy()

# %%
for column in df_encoded.columns:
    if df_encoded[column].dtype == 'object':
        unique_values = df_encoded[column].unique()
        od = OrdinalEncoder(categories=[unique_values])
        encoded_values = od.fit_transform(df_encoded[[column]])
        encoded_df = pd.DataFrame(encoded_values, columns=[column])
        df_encoded[column] = encoded_df[column]
df9 = df_encoded

# %%
df9.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19     0.0  27.900       0.0     0.0     0.0  16884.92400
# 1   18     1.0  33.770       1.0     1.0     1.0   1725.55230
# 2   28     1.0  33.000       3.0     1.0     1.0   4449.46200
# 3   33     1.0  22.705       0.0     1.0     2.0  21984.47061
# 4   32     1.0  28.880       0.0     1.0     2.0   3866.85520

# %%
#The End
